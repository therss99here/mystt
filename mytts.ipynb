# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/100
# 533/533 [==============================] - 71s 133ms/step - loss: 0.3784 - accuracy: 0.8701 - val_loss: 0.5267 - val_accuracy: 0.8365
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/100
# 533/533 [==============================] - 70s 130ms/step - loss: 0.3590 - accuracy: 0.8786 - val_loss: 0.4957 - val_accuracy: 0.8433
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/100
# 533/533 [==============================] - 69s 130ms/step - loss: 0.3475 - accuracy: 0.8791 - val_loss: 0.6007 - val_accuracy: 0.8098
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/100
# 533/533 [==============================] - 69s 130ms/step - loss: 0.3585 - accuracy: 0.8778 - val_loss: 0.5574 - val_accuracy: 0.8229
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/100
# 533/533 [==============================] - 69s 130ms/step - loss: 0.3505 - accuracy: 0.8754 - val_loss: 0.5359 - val_accuracy: 0.8313
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/100
# 533/533 [==============================] - 69s 130ms/step - loss: 0.3448 - accuracy: 0.8785 - val_loss: 0.5441 - val_accuracy: 0.8262
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/100
# 533/533 [==============================] - 72s 135ms/step - loss: 0.3434 - accuracy: 0.8808 - val_loss: 0.5410 - val_accuracy: 0.8264
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/100
# 533/533 [==============================] - 70s 132ms/step - loss: 0.3293 - accuracy: 0.8886 - val_loss: 0.6288 - val_accuracy: 0.8006
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/100
# 533/533 [==============================] - 65s 123ms/step - loss: 0.3195 - accuracy: 0.8914 - val_loss: 0.5034 - val_accuracy: 0.8400
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/100
# 533/533 [==============================] - 54s 102ms/step - loss: 0.3134 - accuracy: 0.8921 - val_loss: 0.5843 - val_accuracy: 0.8278
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/100
# 533/533 [==============================] - 54s 102ms/step - loss: 0.3088 - accuracy: 0.8939 - val_loss: 0.5093 - val_accuracy: 0.8393
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/100
# 533/533 [==============================] - 54s 102ms/step - loss: 0.3132 - accuracy: 0.8922 - val_loss: 0.5391 - val_accuracy: 0.8285
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 00032: early stopping

# %% [markdown]
# **Diagnostic plot**
#
# I’m going to lean on visualization again to understand the performance of the model over a period of time:

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# **Loading the best model**

# %%
from keras.models import load_model
model=load_model('best_model.hdf5')

# %% [markdown]
# Define the function that predicts text for the given audio:

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %% [markdown]
# Prediction time! Make predictions on the validation data:

# %%
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
# Out:
# Audio: no
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Text:",predict(samples))
# Out:
# Text: no

# %% [markdown]
# The best part is yet to come! Here is a script that prompts a user to record voice commands. Record your own voice commands and test it on the model:

# %%
import sounddevice as sd
import soundfile as sf

samplerate = 8000  
duration = 1 # seconds
filename = 'test2.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)
# Out:
# start
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# <ipython-input-76-e2508426f694> in <module>
#       6 filename = 'test2.wav'
#       7 print("start")
# ----> 8 mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
#       9     channels=1, blocking=True)
#      10 print("end")
#
# ~/anaconda3/lib/python3.8/site-packages/sounddevice.py in rec(frames, samplerate, channels, dtype, out, mapping, blocking, **kwargs)
#     272         ctx.callback_exit()
#     273
# --> 274     ctx.start_stream(InputStream, samplerate, ctx.input_channels,
#     275                      ctx.input_dtype, callback, blocking, **kwargs)
#     276     return out
#
# ~/anaconda3/lib/python3.8/site-packages/sounddevice.py in start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2571                      blocking, **kwargs):
#    2572         stop()  # Stop previous playback/recording
# -> 2573         self.stream = StreamClass(samplerate=samplerate,
#    2574                                   channels=channels,
#    2575                                   dtype=dtype,
#
# ~/anaconda3/lib/python3.8/site-packages/sounddevice.py in __init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1413
#    1414         """
# -> 1415         _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1416                              **_remove_self(locals()))
#    1417
#
# ~/anaconda3/lib/python3.8/site-packages/sounddevice.py in __init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     890             userdata = _ffi.NULL
#     891         self._ptr = _ffi.new('PaStream**')
# --> 892         _check(_lib.Pa_OpenStream(self._ptr, iparameters, oparameters,
#     893                                   samplerate, blocksize, stream_flags,
#     894                                   callback_ptr, userdata),
#
# ~/anaconda3/lib/python3.8/site-packages/sounddevice.py in _check(err, msg)
#    2736         raise PortAudioError(errormsg, err, hosterror_info)
#    2737
# -> 2738     raise PortAudioError(errormsg, err)
#    2739
#    2740
#
# PortAudioError: Error opening InputStream: Invalid sample rate [PaErrorCode -9997]

# %% [markdown]
# Let us now read the saved voice command and convert it to text:

# %%
os.listdir('../mytts')
# Out:
# ['.ipynb_checkpoints',
#  'best_model.hdf5',
#  'mytts.ipynb',
#  '.git',
#  'testcom1.wav',
#  'data']

# %%
filepath='../mytts'

# %%
#reading the voice commands
samples, sample_rate = librosa.load(filepath + '/' + 'test2.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate,8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#converting voice commands to text
predict(samples)
# Out:
# 'no'

# %% [markdown]
# Congratulations! You have just built your very own speech-to-text model!
